# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# # Hexane

# %%
raw_time, raw_voltage = np.loadtxt("K5_Hexane_550nm.CSV", delimiter=',', unpack = True, skiprows=17, usecols=(3,4))
plt.plot(raw_time, raw_voltage)

# %%
initialIndex = 243
initialAverage = np.average(raw_voltage[:initialIndex])
print(initialAverage)
raw_deltaA = np.log10(initialAverage/raw_voltage)
plt.plot(raw_time,raw_deltaA)
# Out:
# -2.5065843621399173

# %%
print("Length of time array:", np.shape(raw_time)) #tells me how many x value points I have
index = 245
plt.plot(raw_time[index:], raw_deltaA[index:]) #cuts off beginning of the plot to just show the decay, as shown by the : being put after the variable
time = raw_time[index:] #time of only the decay portion
deltaA = raw_deltaA[index:]
# Out:
# Length of time array: (2483,)

# %%
def exponential(x, a, k, b):
    return a*np.exp(k*x) + b

# %%
optData_first, covData_first = curve_fit(exponential, time, deltaA, p0=(1400,-.1,0)) 
print(f"a = {optData_first[0]}, k = {optData_first[1]}, b = {optData_first[2]}")
# Out:
# a = 0.460603505430704, k = -0.22089496340863973, b = 0.001663107420615993

# %%
plt.subplot(211) #creates the top part of the grid. 211 denotes where it is in space
plt.plot(time, deltaA-exponential(time, optData_first[0], optData_first[1], optData_first[2]),'blueviolet')
plt.ylabel("Residuals")
plt.subplot(212, sharex=plt.gca())
plt.plot(time,deltaA, color='slateblue') #plot of raw data
plt.plot(time, exponential(time, optData_first[0],optData_first[1], optData_first[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)

# %%
plt.plot(time,deltaA, color='slateblue') #plot of raw data
plt.plot(time, exponential(time, optData_first[0],optData_first[1], optData_first[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
print("This is Hexane at 550nm")
# Out:
# This is Hexane at 550nm

# %% [markdown]
# # 1,2-Dichloroethane

# %%
raw_time2, raw_voltage2 = np.loadtxt("K5_1,2-Dichloroethane_550nm.CSV", delimiter=',', unpack = True, skiprows=17, usecols=(3,4))
plt.plot(raw_time2, raw_voltage2)

# %%
initialIndex = 243
initialAverage2 = np.average(raw_voltage2[:initialIndex])
print(initialAverage2)
raw_deltaA2 = np.log10(initialAverage2/raw_voltage2)
plt.plot(raw_time2,raw_deltaA2)
# Out:
# -2.422748971193416

# %%
print("Length of time array:", np.shape(raw_time2)) #tells me how many x value points I have
index = 245
plt.plot(raw_time2[index:], raw_deltaA2[index:]) #cuts off beginning of the plot to just show the decay, as shown by the : being put after the variable
time2 = raw_time2[index:] #time of only the decay portion
deltaA2 = raw_deltaA2[index:]
# Out:
# Length of time array: (2483,)

# %%
optData_first2, covData_first2 = curve_fit(exponential, time2, deltaA2, p0=(1400,-.1,0)) 
print(f"a = {optData_first2[0]}, k = {optData_first2[1]}, b = {optData_first2[2]}")

plt.subplot(211) #creates the top part of the grid. 211 denotes where it is in space
plt.plot(time2, deltaA2-exponential(time2, optData_first2[0], optData_first2[1], optData_first2[2]),'blueviolet')
plt.ylabel("Residuals")
plt.subplot(212, sharex=plt.gca())
plt.plot(time2,deltaA2, color='slateblue') #plot of raw data
plt.plot(time2, exponential(time2, optData_first2[0],optData_first2[1], optData_first2[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
# Out:
# a = 0.036781201647585596, k = -0.1961275114092281, b = 0.001068912222374927

# %%
plt.plot(time2,deltaA2, color='slateblue') #plot of raw data
plt.plot(time2, exponential(time2, optData_first2[0],optData_first2[1], optData_first2[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
print("This is 1,2-dichloroethane at 550nm")
# Out:
# This is 1,2-dichloroethane at 550nm

# %% [markdown]
# # Dodecane

# %%
raw_time3, raw_voltage3 = np.loadtxt("K5_Dodecane_550nm.CSV", delimiter=',', unpack = True, skiprows=17, usecols=(3,4))
plt.plot(raw_time3, raw_voltage3)

# %%
initialIndex = 243
initialAverage3 = np.average(raw_voltage3[:initialIndex])
print(initialAverage3)
raw_deltaA3 = np.log10(initialAverage3/raw_voltage3)
plt.plot(raw_time3,raw_deltaA3)
# Out:
# -2.090172839506173

# %%
print("Length of time array:", np.shape(raw_time3)) #tells me how many x value points I have
index = 245
plt.plot(raw_time3[index:], raw_deltaA3[index:]) #cuts off beginning of the plot to just show the decay, as shown by the : being put after the variable
time3 = raw_time3[index:] #time of only the decay portion
deltaA3 = raw_deltaA3[index:]
# Out:
# Length of time array: (2483,)

# %%
def secondorder(x, a, k, b):
    return a/(1 - k*x*a)+b

# %%
optData_second, covData_second = curve_fit(secondorder, time3, deltaA3, p0=(1400, -0.1, 0))
print(f"a = {optData_second[0]}, k = {optData_second[1]}, b = {optData_second[2]}")
# Out:
# a = 0.22337378121538937, k = -12.131293199845327, b = -0.02950412291152507

# %%
plt.subplot(211) #creates the top part of the grid. 211 denotes where it is in space
plt.plot(time3, deltaA3-secondorder(time3, optData_second[0], optData_second[1], optData_second[2]),'blueviolet')
plt.ylabel("Residuals")
plt.subplot(212, sharex=plt.gca())
plt.plot(time3,deltaA3, color='slateblue') #plot of raw data
plt.plot(time3, secondorder(time3, optData_second[0],optData_second[1], optData_second[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)

# %%
plt.plot(time3,deltaA3, color='slateblue') #plot of raw data
plt.plot(time3, secondorder(time3, optData_second[0],optData_second[1], optData_second[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
print("This is dodecane at 550nm")
# Out:
# This is dodecane at 550nm

# %% [markdown]
# # Hexadecane

# %%
raw_time4, raw_voltage4 = np.loadtxt("K5_Hexadecane_550nm.CSV", delimiter=',', unpack = True, skiprows=17, usecols=(3,4))
plt.plot(raw_time4, raw_voltage4)

# %%
initialIndex = 243
initialAverage4 = np.average(raw_voltage4[:initialIndex])
print(initialAverage4)
raw_deltaA4 = np.log10(initialAverage4/raw_voltage4)
plt.plot(raw_time4,raw_deltaA4)
# Out:
# -2.948674897119341

# %%
print("Length of time array:", np.shape(raw_time4)) #tells me how many x value points I have
index = 245
plt.plot(raw_time4[index:], raw_deltaA4[index:]) #cuts off beginning of the plot to just show the decay, as shown by the : being put after the variable
time4 = raw_time4[index:] #time of only the decay portion
deltaA4 = raw_deltaA4[index:]
# Out:
# Length of time array: (2483,)

# %%
optData_first4, covData_first4 = curve_fit(exponential, time4, deltaA4, p0=(1400,-.1,0)) 
print(f"a = {optData_first4[0]}, k = {optData_first4[1]}, b = {optData_first4[2]}")

plt.subplot(211) #creates the top part of the grid. 211 denotes where it is in space
plt.plot(time4, deltaA4-exponential(time4, optData_first4[0], optData_first4[1], optData_first4[2]),'blueviolet')
plt.ylabel("Residuals")
plt.subplot(212, sharex=plt.gca())
plt.plot(time4,deltaA4, color='slateblue') #plot of raw data
plt.plot(time4, exponential(time4, optData_first4[0],optData_first4[1], optData_first4[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
# Out:
# a = 0.3229805837445649, k = -1.1323072334055166, b = 0.021314115508940277

# %%
plt.plot(time4,deltaA4, color='slateblue') #plot of raw data
plt.plot(time4, exponential(time4, optData_first4[0],optData_first4[1], optData_first4[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
print("Hexadecane at 550nm")
# Out:
# Hexadecane at 550nm

# %% [markdown]
# # Pentane

# %%
raw_time5, raw_voltage5 = np.loadtxt("K5_Pentane_550nm.CSV", delimiter=',', unpack = True, skiprows=17, usecols=(3,4))
plt.plot(raw_time5, raw_voltage5)

# %%
initialIndex = 243
initialAverage5 = np.average(raw_voltage5[:initialIndex])
print(initialAverage5)
raw_deltaA5 = np.log10(initialAverage5/raw_voltage5)
plt.plot(raw_time5,raw_deltaA5)
# Out:
# -2.4475720164609056

# %%
print("Length of time array:", np.shape(raw_time5)) #tells me how many x value points I have
index = 245
plt.plot(raw_time5[index:], raw_deltaA5[index:]) #cuts off beginning of the plot to just show the decay, as shown by the : being put after the variable
time5 = raw_time5[index:] #time of only the decay portion
deltaA5 = raw_deltaA5[index:]
# Out:
# Length of time array: (2483,)

# %%
optData_first5, covData_first5 = curve_fit(exponential, time5, deltaA5, p0=(1400,-.1,0)) 
print(f"a = {optData_first5[0]}, k = {optData_first5[1]}, b = {optData_first5[2]}")

plt.subplot(211) #creates the top part of the grid. 211 denotes where it is in space
plt.plot(time5, deltaA5-exponential(time5, optData_first5[0], optData_first5[1], optData_first5[2]),'blueviolet')
plt.ylabel("Residuals")
plt.subplot(212, sharex=plt.gca())
plt.plot(time5,deltaA5, color='slateblue') #plot of raw data
plt.plot(time5, exponential(time5, optData_first5[0],optData_first5[1], optData_first5[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
# Out:
# a = 0.22117593454774626, k = -1.8380628624003699, b = -0.006486364300992317

# %%
plt.plot(time5,deltaA5, color='slateblue') #plot of raw data
plt.plot(time5, exponential(time5, optData_first5[0],optData_first5[1], optData_first5[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
print("Pentane at 550nm")
# Out:
# Pentane at 550nm

# %% [markdown]
# #  Acetonitrile

# %%
raw_time6, raw_voltage6 = np.loadtxt("K5_Acetonitrile_550nm.CSV", delimiter=',', unpack = True, skiprows=17, usecols=(3,4))
plt.plot(raw_time6, raw_voltage6)

# %%
initialIndex = 243
initialAverage6 = np.average(raw_voltage6[:initialIndex])
print(initialAverage6)
raw_deltaA6 = np.log10(initialAverage6/raw_voltage6)
plt.plot(raw_time6,raw_deltaA6)
# Out:
# -2.4713415637860083

# %%
print("Length of time array:", np.shape(raw_time6)) #tells me how many x value points I have
index = 245
plt.plot(raw_time6[index:], raw_deltaA6[index:]) #cuts off beginning of the plot to just show the decay, as shown by the : being put after the variable
time6 = raw_time6[index:] #time of only the decay portion
deltaA6 = raw_deltaA6[index:]
# Out:
# Length of time array: (2483,)

# %%
optData_first6, covData_first6 = curve_fit(exponential, time6, deltaA6, p0=(1400,-.1,0)) 
print(f"a = {optData_first6[0]}, k = {optData_first6[1]}, b = {optData_first6[2]}")

plt.subplot(211) #creates the top part of the grid. 211 denotes where it is in space
plt.plot(time6, deltaA6-exponential(time6, optData_first6[0], optData_first6[1], optData_first6[2]),'blueviolet')
plt.ylabel("Residuals")
plt.subplot(212, sharex=plt.gca())
plt.plot(time6,deltaA6, color='slateblue') #plot of raw data
plt.plot(time6, exponential(time6, optData_first6[0],optData_first6[1], optData_first6[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
# Out:
# a = 0.12303994034573833, k = -2.3317881461443433, b = 0.0007819275396130635

# %%
plt.plot(time6,deltaA6, color='slateblue') #plot of raw data
plt.plot(time6, exponential(time6, optData_first6[0],optData_first6[1], optData_first6[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
print("Acetonitrile at 550nm")
# Out:
# Acetonitrile at 550nm

# %% [markdown]
# # Methylene Chloride

# %%
raw_time7, raw_voltage7 = np.loadtxt("K5_MethyleneChloride_550nm.CSV", delimiter=',', unpack = True, skiprows=17, usecols=(3,4))
plt.plot(raw_time7, raw_voltage7)

# %%
initialIndex = 243
initialAverage7 = np.average(raw_voltage7[:initialIndex])
print(initialAverage7)
raw_deltaA7 = np.log10(initialAverage7/raw_voltage7)
plt.plot(raw_time7,raw_deltaA7)
# Out:
# -2.529843621399177

# %%
print("Length of time array:", np.shape(raw_time7)) #tells me how many x value points I have
index = 245
plt.plot(raw_time7[index:], raw_deltaA7[index:]) #cuts off beginning of the plot to just show the decay, as shown by the : being put after the variable
time7 = raw_time7[index:] #time of only the decay portion
deltaA7 = raw_deltaA7[index:]
# Out:
# Length of time array: (2483,)

# %%
optData_first7, covData_first7 = curve_fit(exponential, time7, deltaA7, p0=(1400,-.1,0)) 
print(f"a = {optData_first7[0]}, k = {optData_first7[1]}, b = {optData_first7[2]}")

plt.subplot(211) #creates the top part of the grid. 211 denotes where it is in space
plt.plot(time7, deltaA7-exponential(time7, optData_first7[0], optData_first7[1], optData_first7[2]),'blueviolet')
plt.ylabel("Residuals")
plt.subplot(212, sharex=plt.gca())
plt.plot(time7,deltaA7, color='slateblue') #plot of raw data
plt.plot(time7, exponential(time7, optData_first7[0],optData_first7[1], optData_first7[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
# Out:
# a = 0.10873229287204135, k = -0.9327531009685789, b = 0.0010421406540560057

# %%
plt.plot(time7,deltaA7, color='slateblue') #plot of raw data
plt.plot(time7, exponential(time7, optData_first7[0],optData_first7[1], optData_first7[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
print("Methylene Chloride at 550")
# Out:
# Methylene Chloride at 550

# %% [markdown]
# # Ethyl Acetate

# %%
raw_time8, raw_voltage8 = np.loadtxt("K5_EthylAcetate_550nm.CSV", delimiter=',', unpack = True, skiprows=17, usecols=(3,4))
plt.plot(raw_time8, raw_voltage8)

# %%
initialIndex = 243
initialAverage8 = np.average(raw_voltage8[:initialIndex])
print(initialAverage8)
raw_deltaA8 = np.log10(initialAverage8/raw_voltage8)
plt.plot(raw_time8,raw_deltaA8)
# Out:
# -2.546008230452675

# %%
print("Length of time array:", np.shape(raw_time8)) #tells me how many x value points I have
index = 245
plt.plot(raw_time8[index:], raw_deltaA8[index:]) #cuts off beginning of the plot to just show the decay, as shown by the : being put after the variable
time8 = raw_time8[index:] #time of only the decay portion
deltaA8 = raw_deltaA8[index:]
# Out:
# Length of time array: (2483,)

# %%
optData_first8, covData_first8 = curve_fit(exponential, time8, deltaA8, p0=(1400,-.1,0)) 
print(f"a = {optData_first8[0]}, k = {optData_first8[1]}, b = {optData_first8[2]}")

plt.subplot(211) #creates the top part of the grid. 211 denotes where it is in space
plt.plot(time8, deltaA8-exponential(time8, optData_first8[0], optData_first8[1], optData_first8[2]),'blueviolet')
plt.ylabel("Residuals")
plt.subplot(212, sharex=plt.gca())
plt.plot(time8,deltaA8, color='slateblue') #plot of raw data
plt.plot(time8, exponential(time8, optData_first8[0],optData_first8[1], optData_first8[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
# Out:
# a = 0.2608633314007269, k = -2.705110991563189, b = 0.0005641333907058527

# %%
plt.plot(time8,deltaA8, color='slateblue') #plot of raw data
plt.plot(time8, exponential(time8, optData_first8[0],optData_first8[1], optData_first8[2]), color='orange') #plot of line of best fit
plt.legend(("Raw data", "Model"))
plt.ylabel("$\Delta$A")
plt.xlabel("Time (s)")
plt.subplots_adjust(hspace=0)
print("Ethyl Acetate at 550nm")
# Out:
# Ethyl Acetate at 550nm
